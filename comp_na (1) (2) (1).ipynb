# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn as sk
from sklearn import preprocessing
from sklearn import utils

# %%
d = pd.read_csv('train_dataset.csv')
test = pd.read_csv('test_dataset.csv')
d.head()
# Out:
#    Unnamed: 0   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0       11073  29076    636.353       235.061516       158.033619
# 1       13172  38091    755.186       271.077683       179.756984
# 2       11587  30969    651.527       230.164083       171.903953
# 3       12492  34589    685.425       253.001232       174.609358
# 4         430  35954    710.093       251.660769       182.014822
#
#    AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  \
# 0      1.487415      0.740272       29490     192.407674  0.693524  0.985961
# 1      1.508023      0.748513       38716     220.224811  0.706318  0.983857
# 2      1.338911      0.664964       31318     198.572293  0.733689  0.988856
# 3      1.448956      0.723664       34965     209.857291  0.784331  0.989246
# 4      1.382639      0.690581       36380     213.958067  0.794564  0.988290
#
#    roundness  Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  \
# ...

# %%
d.describe()
# Out:
#          Unnamed: 0           Area     Perimeter  MajorAxisLength  \
# count  10888.000000   10888.000000  10888.000000     10888.000000
# mean    6826.065393   52870.780860    854.036474       319.642780
# std     3932.496944   29017.700725    213.001952        85.293958
# min        1.000000   20420.000000    524.736000       183.601165
# 25%     3403.750000   36259.000000    702.899250       252.983273
# 50%     6830.000000   44567.500000    793.646500       296.241223
# 75%    10253.500000   61247.750000    976.670750       375.985540
# max    13610.000000  254616.000000   1985.370000       738.860153
#
#        MinorAxisLength  AspectRation  Eccentricity     ConvexArea  \
# count     10888.000000  10888.000000  10888.000000   10888.000000
# mean        202.013542      1.582640      0.750758   53587.306209
# std          44.579910      0.246178      0.091870   29461.902399
# min         122.512653      1.024868      0.218951   20684.000000
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10888 entries, 0 to 10887
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10888 non-null  int64
#  1   Area             10888 non-null  int64
#  2   Perimeter        10888 non-null  float64
#  3   MajorAxisLength  10888 non-null  float64
#  4   MinorAxisLength  10888 non-null  float64
#  5   AspectRation     10888 non-null  float64
#  6   Eccentricity     10888 non-null  float64
#  7   ConvexArea       10888 non-null  int64
#  8   EquivDiameter    10888 non-null  float64
#  9   Extent           10888 non-null  float64
#  10  Solidity         10888 non-null  float64
#  11  roundness        10888 non-null  float64
#  12  Compactness      10888 non-null  float64
#  13  ShapeFactor1     10888 non-null  float64
#  14  ShapeFactor2     10888 non-null  float64
#  15  ShapeFactor3     10888 non-null  float64
# ...

# %%
d.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10883    False
# 10884    False
# 10885    False
# 10886    False
# 10887    False
# Length: 10888, dtype: bool

# %%
u =  d['y_label'].unique()
u
# Out:
# array(['DERMASON', 'SEKER', 'BARBUNYA', 'SIRA', 'CALI', 'HOROZ', 'BOMBAY'],
#       dtype=object)

# %%
der = d[d.y_label == u[0]]
der
# Out:
#        Unnamed: 0   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0           11073  29076    636.353       235.061516       158.033619
# 1           13172  38091    755.186       271.077683       179.756984
# 2           11587  30969    651.527       230.164083       171.903953
# 3           12492  34589    685.425       253.001232       174.609358
# 5           13042  37342    716.591       265.585855       179.652361
# ...           ...    ...        ...              ...              ...
# 10874       11636  31193    659.196       241.968960       164.991475
# 10877       13526  41141    748.048       273.787182       191.686234
# 10881       11284  29882    649.082       247.427847       154.779257
# 10882       11964  32384    657.952       238.548336       173.086148
# 10884       13418  39857    755.392       283.623668       179.430885
#
#        AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# ...

# %%
test.drop(columns=['ShapeFactor1', 'ShapeFactor2' , 'ShapeFactor3','ShapeFactor4'], inplace= True)

# %%
d.drop(columns=['ShapeFactor1', 'ShapeFactor2' , 'ShapeFactor3','ShapeFactor4'] , inplace= True)

# %%
sek = d[d.y_label == u[1]]
sek
# Out:
#        Unnamed: 0   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 4             430  35954    710.093       251.660769       182.014822
# 9             577  36851    699.211       240.537152       195.536548
# 16           1698  44538    761.462       265.180921       214.272337
# 17            761  37927    697.748       233.259871       207.162748
# 19            796  38117    699.123       238.594017       203.595789
# ...           ...    ...        ...              ...              ...
# 10862        1184  40265    729.520       257.451054       199.649689
# 10869         769  37987    701.371       244.466475       198.010966
# 10870        1685  44442    766.629       263.349682       215.203537
# 10878         466  36140    693.003       236.506099       194.837648
# 10886         860  38426    711.412       246.696608       198.555755
#
#        AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# ...

# %%
x = d.iloc[:, 0:13].values
y = d.iloc[:, 13].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20 ,stratify=y)

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()   
classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=classifier.predict(x_test) 
#y_test is the actual values & y_predict is the prediction values

''' making the confusion matrix'''
#to evaluate the performance of model
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test , y_pred)
cm
# Out:
# array([[207,   0,   0,   0,   0,   5,   0],
#        [  0,  81,   0,   0,   0,   0,   0],
#        [  9,   0, 250,   0,   3,   1,   0],
#        [  0,   0,   0, 575,   0,   0,   0],
#        [  0,   0,   2,   2, 295,   0,   5],
#        [  9,   0,   0,   0,   0, 314,   0],
#        [  0,   0,   0,   9,   0,   0, 411]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA       0.92      0.98      0.95       212
#       BOMBAY       1.00      1.00      1.00        81
#         CALI       0.99      0.95      0.97       263
#     DERMASON       0.98      1.00      0.99       575
#        HOROZ       0.99      0.97      0.98       304
#        SEKER       0.98      0.97      0.98       323
#         SIRA       0.99      0.98      0.98       420
#
#     accuracy                           0.98      2178
#    macro avg       0.98      0.98      0.98      2178
# weighted avg       0.98      0.98      0.98      2178

# %%
te1 = classifier.predict(test)
prediction = pd.DataFrame(te1, columns=['y_label']).to_csv('ffprediction.csv')

# %%
te = pd.read_csv('ffprediction.csv')
te
# Out:
#       Unnamed: 0   y_label
# 0              0     SEKER
# 1              1  BARBUNYA
# 2              2     SEKER
# 3              3     SEKER
# 4              4  DERMASON
# ...          ...       ...
# 2718        2718  BARBUNYA
# 2719        2719     SEKER
# 2720        2720  DERMASON
# 2721        2721      CALI
# 2722        2722      SIRA
#
# [2723 rows x 2 columns]
